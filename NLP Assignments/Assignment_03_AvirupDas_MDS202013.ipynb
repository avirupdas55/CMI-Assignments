# %% [markdown]
# # NLP2022: Assignment 3
#
# ### -Avirup Das (MDS202013)

# %%
# Importing necessary packages
import os, re, json, math, nltk, pickle, spacy, string
import scipy, logging, gensim, gc, random, torch
import pandas as pd
import numpy as np
import numpy.matlib as mat
from tqdm import tqdm
from gensim.models import Word2Vec, word2vec
from nltk.tokenize import sent_tokenize
nltk.download('punkt')

# Mounting google drive
from google.colab import drive
drive.mount('/content/drive')

# Setting paths
path_to_json = 'pdf_json/'
drive_directory = 'drive/MyDrive/Data/NLP2022/'
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Loading english documents from drive
with open(drive_directory+'eng_corpus.txt','r') as f:
  eng_corpus= f.read()

eng_corpus = eng_corpus.split('\n')

# %%
# Pre-processing corpus
def rem_quote(corpus):
  # Remove apostrophe (\') and quotes
  return re.sub('[\"\']', '', re.sub('\'', '', corpus))

def rem_contractions(corpus):
  '''
    Removes all contractions from the corpus
  '''
  # Removing specific contractions
  corpus = re.sub(r"won\'t", " will not ", corpus)
  corpus = re.sub(r"can\'t", " can not ", corpus)
  corpus = re.sub(r"e.g.", " example ", corpus)
  corpus = re.sub(r"i.e.", " that is ", corpus)

  # Removing general contractions
  corpus = re.sub(r"n\'t", " not ", corpus)
  corpus = re.sub(r"\'re", " are ", corpus)
  corpus = re.sub(r"\'s", " is ", corpus)
  corpus = re.sub(r"\'d", " would ", corpus)
  corpus = re.sub(r"\'ll", " will ", corpus)
  corpus = re.sub(r"\'t", " not ", corpus)
  corpus = re.sub(r"\'ve", " have ", corpus)
  corpus = re.sub(r"\'m", " am ", corpus)

  return corpus

def rem_url(corpus):
  '''
  Remove all urls from the corpus. Searching for the regex pattern http(s)://
  or http(s):\\ followed by any set of characters unless it is a blank space (' '),
  newline ('\n'), tab-space ('\t'), any white space ('\s') or ending brackets ')'
  '''
  regex = re.compile(r'https?:/\/\.*[^\r\n\s\t\)]*')
  corpus = re.sub(regex, '', corpus)

  # Removing email IDs
  return re.sub(re.compile(r"\S*@\S*\s?"),'', corpus)

def rem_brackets(corpus):
  '''
  Remove parenthesis and all characters appearing between them (if any).
  Also remove citations which are in third brackets (eg: [3])
  '''
  regex = re.compile(r'[\[\(]+[^\n\[\(]*[\)\]]+')
  return re.sub(regex, '', corpus)

def rem_nums_chars(corpus):
  '''
   Remove all special characters (except sentence delimiters .?!),
   digits and single letters (except 'a') and then encode and
   decode in ASCII to remove all invalid characters
  '''
  corpus = re.sub(r'''[\[\]\(\)\{\}['",:;#$%&><=*\\\/\+\-\@]''', ' ', corpus)
  corpus = re.sub(r'[0-9?]', ' ', corpus)
  corpus = re.sub(r' [b-zB-Z] ', ' ', corpus)
  corpus = corpus.encode("ascii", "ignore")
  return corpus.decode()

def remove_extra_space(corpus):
  # Remove extra spaces and tabs to be just one white space. 
  return re.sub(re.compile(r'(?<= ) +'), '', corpus)

def correct_sentence_end(text):
  '''
   Function to correct sentence structure. There should not be any whitespace before .,! or ? and 
   a whitespace after .! or ?. This is important to extract out sentences from a text. 
   We also handle decimals since there should not be spaces after decimal points.
  '''
  pattern1 = re.compile(r'( +)([.!?])')
  text = re.sub(pattern1, '\g<2>', text)
  pattern2 = re.compile(r'([?!])([^ ])')
  text = re.sub(pattern2, '\g<1>' + ' ' + '\g<2>', text)
  return re.sub('(\.)([^ \d])', '\g<1>' + ' ' + '\g<2>', text)

def preprocess(corpus):
  # Defining our sequence of pre-processing steps
  corpus = rem_contractions(corpus)
  corpus = rem_url(corpus)
  corpus = rem_brackets(corpus)
  corpus = rem_quote(corpus)
  corpus = rem_nums_chars(corpus)
  corpus = remove_extra_space(corpus)
  corpus = correct_sentence_end(corpus)
  return corpus

# %%
# Pre-process entire corpus
def preprocess_corpus(docs, batch_size=6000):
  '''
   Pre-processing the whole corpus in batches to avoid memory-overflow
   and writing batches to disk
  '''
  n_batches = math.ceil(len(docs)/batch_size)
  corpus = ''
  for i in range(n_batches):
    batch_begin= batch_size*i
    batch = docs[batch_begin:batch_begin+batch_size]
    if len(corpus)!=0:
      corpus = corpus+'\n'+ preprocess('\n'.join(batch))
    else:
      corpus = preprocess('\n'.join(batch))
    print(f'Pre-processing {i+1}-th batch: Done')
  # Save processed corpus
  with open(drive_directory+f'processed_corpus.txt', 'w') as f:
      f.write(corpus)
  return corpus

# %%
# %%time
eng_corpus = preprocess_corpus(eng_corpus)
# Out:
# Pre-processing 1-th batch: Done
# Pre-processing 2-th batch: Done
# Pre-processing 3-th batch: Done
# Pre-processing 4-th batch: Done
# Pre-processing 5-th batch: Done
# Pre-processing 6-th batch: Done
# Pre-processing 7-th batch: Done
# Pre-processing 8-th batch: Done
# Pre-processing 9-th batch: Done
# Pre-processing 10-th batch: Done
# CPU times: user 7min 2s, sys: 17.2 s, total: 7min 19s
# Wall time: 7min 24s

# %%
with open(drive_directory+f'processed_corpus.txt', 'r') as f:
  eng_corpus=f.read()

# %%
# Taking 2000 random samples from english docs
doc_idx=random.sample(range(0, len(eng_corpus.split('\n'))), 2000)
print(doc_idx)
# Out:
# [2852, 24831, 17791, 33971, 26516, 3930, 26813, 10909, 19192, 52220, 38346, 52619, 4106, 32009, 6057, 20074, 26593, 21600, 50588, 19388, 52806, 50363, 41305, 13372, 7065, 19563, 93, 30302, 11357, 10419, 49000, 4150, 28202, 20810, 30075, 3112, 41684, 37611, 22029, 2330, 32915, 42384, 28824, 23960, 26260, 50034, 22795, 38728, 26796, 2048, 14614, 37166, 10952, 17072, 49845, 41960, 46945, 40132, 5574, 21974, 1467, 8489, 48358, 34020, 25710, 44096, 6493, 6375, 19057, 34451, 29988, 14869, 37013, 14002, 23415, 41536, 7834, 14657, 22581, 12145, 10725, 20103, 39195, 20841, 22118, 18799, 3229, 14390, 27217, 14805, 15625, 49610, 51459, 9705, 28118, 17660, 6070, 31178, 28754, 46599, 13744, 30570, 46395, 32255, 15858, 15627, 8022, 26176, 2516, 42461, 46114, 11349, 12072, 11257, 19972, 37745, 42901, 13961, 46088, 10202, 41773, 35516, 1546, 22988, 19570, 17356, 17954, 13317, 34704, 41914, 28876, 42048, 5980, 11063, 37399, 25244, 26009, 15023, 52447, 44108, 32803, 5782, 16355, 21812, 15250, 47221, 30354, 977, 15485, 1038, 3849, 9772, 42973, 22281, 9145, 15816, 30284, 53099, 22262, 53955, 49544, 1319, 29496, 22303, 44661, 53413, 5389, 8103, 5796, 43049, 42413, 8739, 36119, 8248, 34349, 46084, 40657, 15678, 16024, 46721, 26900, 46427, 52296, 14312, 48466, 49933, 45491, 33233, 29556, 48651, 24961, 15236, 40801, 8854, 53152, 51750, 10032, 10986, 49446, 2182, 29966, 2834, 3079, 20035, 21471, 51304, 7326, 10436, 45712, 29275, 10143, 51456, 41575, 34851, 18543, 25105, 47173, 47381, 31566, 28214, 45315, 18239, 52381, 4397, 2505, 8271, 25912, 26277, 24852, 27157, 3985, 30565, 42276, 33588, 18757, 39862, 36524, 47185, 11619, 18442, 13396, 5830, 54774, 7990, 25155, 51802, 52242, 9207, 10079, 16610, 51482, 32705, 29487, 48616, 16672, 23179, 7400, 18049, 25794, 51621, 21632, 13191, 3623, 7095, 30431, 35922, 1860, 47932, 48333, 41769, 14172, 34217, 53762, 2928, 39891, 24935, 21456, 38045, 30062, 38244, 38389, 5541, 16939, 31802, 28654, 48035, 27789, 40916, 51954, 16292, 12916, 20587, 48743, 11641, 16595, 13715, 40781, 23157, 8204, 36336, 26966, 2725, 35434, 4625, 47137, 12455, 51222, 35806, 19751, 12798, 10764, 44240, 49352, 31150, 2770, 46305, 41167, 50324, 29168, 37576, 33229, 35060, 15570, 32627, 6170, 15462, 36766, 45757, 20150, 44058, 26389, 35216, 40411, 30991, 29588, 53061, 15107, 19581, 7925, 37160, 32113, 153, 12787, 13498, 34179, 24352, 27008, 47094, 25195, 16095, 15457, 46746, 52413, 51043, 4131, 16311, 16982, 38048, 26528, 4959, 42515, 1826, 26800, 30951, 32215, 41352, 15390, 46312, 24181, 50556, 5124, 42871, 8054, 27148, 3789, 19758, 6491, 21735, 39317, 24189, 47908, 47269, 39561, 6369, 33324, 51532, 20808, 5362, 5375, 35355, 18783, 43513, 36304, 21041, 4094, 1685, 51133, 40819, 17094, 32975, 8013, 28486, 19733, 4935, 33250, 36661, 10137, 24349, 23987, 47977, 21586, 30217, 36008, 23520, 34552, 16724, 18018, 13054, 761, 38420, 14501, 37426, 15346, 53583, 2537, 1149, 32471, 51749, 12217, 5171, 16673, 42691, 34279, 24286, 22766, 45967, 26531, 47154, 53904, 46075, 54305, 50925, 31524, 53901, 46939, 5918, 5232, 27462, 33344, 12644, 40256, 2811, 32522, 42054, 14568, 7903, 36869, 53218, 36946, 13502, 9898, 13256, 37445, 32899, 49827, 22446, 32447, 17276, 25619, 51392, 6946, 14105, 4542, 22770, 49085, 28978, 45702, 37563, 20282, 33769, 23385, 52327, 17258, 33788, 52933, 43677, 26812, 10705, 41170, 41629, 53001, 15758, 575, 11416, 20429, 1494, 11651, 35149, 9105, 26685, 9200, 7185, 27022, 25764, 16890, 54248, 22398, 30835, 52828, 45587, 40503, 12609, 44198, 49943, 24768, 45309, 27966, 30105, 19664, 14783, 46670, 39711, 40089, 5770, 25396, 54241, 33388, 48215, 16691, 8945, 6686, 54109, 39611, 21566, 45435, 19491, 11902, 19780, 35122, 20492, 2342, 14163, 47994, 13266, 48664, 4394, 37817, 22298, 26157, 47762, 22325, 1878, 21411, 22707, 29488, 53740, 41390, 26554, 47427, 21721, 9138, 31011, 30874, 9925, 13696, 54727, 21281, 54116, 20543, 31783, 26303, 51237, 8362, 29815, 34293, 54457, 14359, 1347, 24534, 52670, 9468, 36855, 51514, 5582, 43697, 22013, 26916 ...

# %%
# Extracting sentences from the sample which have length greater than 5 but less than 20
sentences, docs = [], eng_corpus.split('\n')
for doc in [docs[i] for i in doc_idx]:
  try:
    for sentence in sent_tokenize(doc):
      if len(sentence.split())>5 and len(sentence.split())<20:
        sentences.append(sentence)
  except:
    pass

del docs

# %%
# Compute Word vectors
def word_vecs(corpus_path, size=50, save_model=True): 
  logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
  text = word2vec.Text8Corpus(corpus_path)
  model = word2vec.Word2Vec(text, vector_size=size, window=5, min_count=20, workers=10, epochs=10)
  if save_model:
    model.save(drive_directory+'word2vec3.bin')
  return model

# model = word_vecs(drive_directory+'processed_corpus.txt')
model = word_vecs(drive_directory+'processed_corpus.txt')
# Out:
# 2022-05-19 03:16:51,969 : INFO : collecting all words and their counts
# 2022-05-19 03:16:54,304 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2022-05-19 03:17:30,063 : INFO : PROGRESS: at sentence #10000, processed 100000000 words, keeping 474310 word types
# 2022-05-19 03:18:03,407 : INFO : PROGRESS: at sentence #20000, processed 200000000 words, keeping 715089 word types
# 2022-05-19 03:18:11,151 : INFO : collected 764945 word types from a corpus of 222967702 raw words and 22297 sentences
# 2022-05-19 03:18:11,153 : INFO : Creating a fresh vocabulary
# 2022-05-19 03:18:11,934 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=20 retains 94068 unique words (12.297354711776663%% of original 764945, drops 670877)', 'datetime': '2022-05-19T03:18:11.934110', 'gensim': '4.1.2', 'python': '3.7.13 (default, Apr 24 2022, 01:04:09) \n[GCC 7.5.0]', 'platform': 'Linux-5.4.188+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'prepare_vocab'}
# 2022-05-19 03:18:11,936 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=20 leaves 221129409 word corpus (99.17553395244661%% of original 222967702, drops 1838293)', 'datetime': '2022-05-19T03:18:11.936256', 'gensim': '4.1.2', 'python': '3.7.13 (default, Apr 24 2022, 01:04:09) \n[GCC 7.5.0]', 'platform': 'Linux-5.4.188+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'prepare_vocab'}
# 2022-05-19 03:18:12,587 : INFO : deleting the raw counts dictionary of 764945 items
# 2022-05-19 03:18:12,620 : INFO : sample=0.001 downsamples 28 most-common words
# 2022-05-19 03:18:12,622 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 160921001.25740647 word corpus (72.8%% of prior 221129409)', 'datetime': '2022-05-19T03:18:12.622187', 'gensim': '4.1.2', 'python': '3.7.13 (default, Apr 24 2022, 01:04:09) \n[GCC 7.5.0]', 'platform': 'Linux-5.4.188+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'prepare_vocab'}
# 2022-05-19 03:18:13,734 : INFO : estimated required memory for 94068 words and 50 dimensions: 84661200 bytes
# 2022-05-19 03:18:13,741 : INFO : resetting layer weights
# 2022-05-19 03:18:13,781 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2022-05-19T03:18:13.781227', 'gensim': '4.1.2', 'python': '3.7.13 (default, Apr 24 2022, 01:04:09) \n[GCC 7.5.0]', 'platform': 'Linux-5.4.188+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'build_vocab'}
# 2022-05-19 03:18:13,785 : INFO : Word2Vec lifecycle event {'msg': 'training model with 10 workers on 94068 vocabulary and 50 features, using sg=0 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2022-05-19T03:18:13.785628', 'gensim': '4.1.2', 'python': '3.7.13 (default, Apr 24 2022, 01:04:09) \n[GCC 7.5.0]', 'platform': 'Linux-5.4.188+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'train'}
# 2022-05-19 03:18:14,871 : INFO : EPOCH 1 - PROGRESS: at 0.23% examples, 350520 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:18:15,880 : INFO : EPOCH 1 - PROGRESS: at 0.53% examples, 414188 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:18:16,899 : INFO : EPOCH 1 - PROGRESS: at 0.83% examples, 435064 words/s, in_qsize 20, out_qsize 1
# 2022-05-19 03:18:17,975 : INFO : EPOCH 1 - PROGRESS: at 1.13% examples, 439283 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:18:19,008 : INFO : EPOCH 1 - PROGRESS: at 1.42% examples, 440038 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:18:20,018 : INFO : EPOCH 1 - PROGRESS: at 1.74% examples, 449944 words/s, in_qsize 16, out_qsize 0
# 2022-05-19 03:18:21,049 : INFO : EPOCH 1 - PROGRESS: at 2.04% examples, 454116 words/s, in_qsize 16, out_qsize 1
# 2022-05-19 03:18:22,033 : INFO : EPOCH 1 - PROGRESS: at 2.31% examples, 453120 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:18:23,047 : INFO : EPOCH 1 - PROGRESS: at 2.62% examples, 457323 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:18:24,072 : INFO : EPOCH 1 - PROGRESS: at 2.90% examples, 455132 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:18:25,073 : INFO : EPOCH 1 - PROGRESS: at 3.22% examples, 459445 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:18:26,106 : INFO : EPOCH 1 - PROGRESS: at 3.50% examples, 459448 words/s, in_qsize 19, out_qsize 4
# 2022-05-19 03:18:27,082 : INFO : EPOCH 1 - PROGRESS: at 3.80% examples, 461254 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:18:28,160 : INFO : EPOCH 1 - PROGRESS: at 4.10% examples, 459851 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:18:29,188 : INFO : EPOCH 1 - PROGRESS: at 4.40% examples, 460406 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:18:30,240 : INFO : EPOCH 1 - PROGRESS: at 4.70% examples, 460762 words/s, in_qsize 19, out_qsize 2
# 2022-05-19 03:18:31,247 : INFO : EPOCH 1 - PROGRESS: at 5.01% examples, 462735 words/s, in_qsize 15, out_qsize 3
# 2022-05-19 03:18:32,268 : INFO : EPOCH 1 - PROGRESS: at 5.32% examples, 463613 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:18:33,269 : INFO : EPOCH 1 - PROGRESS: at 5.60% examples, 462651 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:18:34,344 : INFO : EPOCH 1 - PROGRESS: at 5.91% examples, 462867 words/s, in_qsize 16, out_qsize 3
# 2022-05-19 03:18:35,382 : INFO : EPOCH 1 - PROGRESS: at 6.23% examples, 464344 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:18:36,433 : INFO : EPOCH 1 - PROGRESS: at 6.53% examples, 464474 words/s, in_qsize 18, out_qsize 4
# 2022-05-19 03:18:37,447 : INFO : EPOCH 1 - PROGRESS: at 6.84% examples, 465310 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:18:38,453 : INFO : EPOCH 1 - PROGRESS: at 7.11% examples, 464428 words/s, in_qsize 16, out_qsize 4
# 2022-05-19 03:18:39,477 : INFO : EPOCH 1 - PROGRESS: at 7.43% examples, 465607 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:18:40,506 : INFO : EPOCH 1 - PROGRESS: at 7.73% examples, 465734 words/s, in_qsize 14, out_qsize 4
# 2022-05-19 03:18:41,507 : INFO : EPOCH 1 - PROGRESS: at 8.01% examples, 465564 words/s, in_qsize 20, out_qsize 2
# 2022-05-19 03:18:42,524 : INFO : EPOCH 1 - PROGRESS: at 8.30% examples, 465049 words/s, in_qsize 18, out_qsize 5
# 2022-05-19 03:18:43,529 : INFO : EPOCH 1 - PROGRESS: at 8.62% examples, 466238 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:18:44,540 : INFO : EPOCH 1 - PROGRESS: at 8.92% examples, 466929 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:18:45,555 : INFO : EPOCH 1 - PROGRESS: at 9.21% examples, 466599 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:18:46,583 : INFO : EPOCH 1 - PROGRESS: at 9.52% examples, 467100 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:18:47,676 : INFO : EPOCH 1 - PROGRESS: at 9.83% examples, 466690 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:18:48,677 : INFO : EPOCH 1 - PROGRESS: at 10.12% examples, 466868 words/s, in_qsize 19, out_qsize 1
# 2022-05-19 03:18:49,684 : INFO : EPOCH 1 - PROGRESS: at 10.42% examples, 467305 words/s, in_qsize 17, out_qsize 3
# 2022-05-19 03:18:50,693 : INFO : EPOCH 1 - PROGRESS: at 10.72% examples, 467461 words/s, in_qsize 19, out_qsize 4
# 2022-05-19 03:18:51,696 : INFO : EPOCH 1 - PROGRESS: at 11.00% examples, 467055 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:18:52,734 : INFO : EPOCH 1 - PROGRESS: at 11.30% examples, 466876 words/s, in_qsize 15, out_qsize 4
# 2022-05-19 03:18:53,736 : INFO : EPOCH 1 - PROGRESS: at 11.61% examples, 467626 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:18:54,760 : INFO : EPOCH 1 - PROGRESS: at 11.93% examples, 468410 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:18:55,855 : INFO : EPOCH 1 - PROGRESS: at 12.23% examples, 467704 words/s, in_qsize 17, out_qsize 2
# 2022-05-19 03:18:56,858 : INFO : EPOCH 1 - PROGRESS: at 12.53% examples, 468211 words/s, in_qsize 17, out_qsize 1
# 2022-05-19 03:18:57,927 : INFO : EPOCH 1 - PROGRESS: at 12.84% examples, 468282 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:18:58,962 : INFO : EPOCH 1 - PROGRESS: at 13.15% examples, 468413 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:19:00,001 : INFO : EPOCH 1 - PROGRESS: at 13.46% examples, 468631 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:19:01,002 : INFO : EPOCH 1 - PROGRESS: at 13.74% examples, 468351 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:19:02,007 : INFO : EPOCH 1 - PROGRESS: at 13.99% examples, 466868 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:19:03,104 : INFO : EPOCH 1 - PROGRESS: at 14.20% examples, 463490 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:19:04,156 : INFO : EPOCH 1 - PROGRESS: at 14.43% examples, 460979 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:19:05,276 : INFO : EPOCH 1 - PROGRESS: at 14.67% examples, 458360 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:19:06,278 : INFO : EPOCH 1 - PROGRESS: at 14.87% examples, 455805 words/s, in_qsize 11, out_qsize 8
# 2022-05-19 03:19:07,299 : INFO : EPOCH 1 - PROGRESS: at 15.10% examples, 454026 words/s, in_qsize 17, out_qsize 6
# 2022-05-19 03:19:08,301 : INFO : EPOCH 1 - PROGRESS: at 15.31% examples, 451909 words/s, in_qsize 19, out_qsize 5
# 2022-05-19 03:19:09,302 : INFO : EPOCH 1 - PROGRESS: at 15.54% examples, 450621 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:19:10,392 : INFO : EPOCH 1 - PROGRESS: at 15.76% examples, 448163 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:19:11,393 : INFO : EPOCH 1 - PROGRESS: at 15.98% examples, 446355 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:19:12,445 : INFO : EPOCH 1 - PROGRESS: at 16.20% examples, 444214 words/s, in_qsize 16, out_qsize 3
# 2022-05-19 03:19:13,515 : INFO : EPOCH 1 - PROGRESS: at 16.43% examples, 442634 words/s, in_qsize 19, out_qsize 5
# 2022-05-19 03:19:14,529 : INFO : EPOCH 1 - PROGRESS: at 16.66% examples, 441336 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:19:15,568 : INFO : EPOCH 1 - PROGRESS: at 16.89% examples, 439894 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:19:16,629 : INFO : EPOCH 1 - PROGRESS: at 17.18% examples, 439946 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:19:17,712 : INFO : EPOCH 1 - PROGRESS: at 17.50% examples, 440801 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:19:18,688 : INFO : EPOCH 1 - PROGRESS: at 17.79% examples, 441112 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:19:19,711 : INFO : EPOCH 1 - PROGRESS: at 18.10% examples, 441931 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:19:20,763 : INFO : EPOCH 1 - PROGRESS: at 18.40% examples, 442107 words/s, in_qsize 12, out_qsize 8
# 2022-05-19 03:19:21,772 : INFO : EPOCH 1 - PROGRESS: at 18.72% examples, 443147 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:19:22,788 : INFO : EPOCH 1 - PROGRESS: at 19.02% examples, 443489 words/s, in_qsize 17, out_qsize 1
# 2022-05-19 03:19:23,800 : INFO : EPOCH 1 - PROGRESS: at 19.30% examples, 443586 words/s, in_qsize 18, out_qsize 2
# 2022-05-19 03:19:24,823 : INFO : EPOCH 1 - PROGRESS: at 19.60% examples, 444086 words/s, in_qsize 17, out_qsize 2
# 2022-05-19 03:19:25,842 : INFO : EPOCH 1 - PROGRESS: at 19.92% examples, 444832 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:19:26,849 : INFO : EPOCH 1 - PROGRESS: at 20.22% examples, 445434 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:19:27,932 : INFO : EPOCH 1 - PROGRESS: at 20.51% examples, 445247 words/s, in_qsize 15, out_qsize 4
# 2022-05-19 03:19:28,936 : INFO : EPOCH 1 - PROGRESS: at 20.83% examples, 446152 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:19:29,938 : INFO : EPOCH 1 - PROGRESS: at 21.12% examples, 446443 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:19:30,990 : INFO : EPOCH 1 - PROGRESS: at 21.43% examples, 446721 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:19:32,028 : INFO : EPOCH 1 - PROGRESS: at 21.74% examples, 447123 words/s, in_qsize 18, out_qsize 0
# 2022-05-19 03:19:33,085 : INFO : EPOCH 1 - PROGRESS: at 22.06% examples, 447601 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:19:34,102 : INFO : EPOCH 1 - PROGRESS: at 22.35% examples, 447867 words/s, in_qsize 19, out_qsize 1
# 2022-05-19 03:19:35,128 : INFO : EPOCH 1 - PROGRESS: at 22.65% examples, 448118 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:19:36,173 : INFO : EPOCH 1 - PROGRESS: at 22.94% examples, 448226 words/s, in_qsize 16, out_qsize 4
# 2022-05-19 03:19:37,213 : INFO : EPOCH 1 - PROGRESS: at 23.25% examples, 448508 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:19:38,217 : INFO : EPOCH 1 - PROGRESS: at 23.55% examples, 448986 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:19:39,259 : INFO : EPOCH 1 - PROGRESS: at 23.85% examples, 449004 words/s, in_qsize 15, out_qsize 3
# 2022-05-19 03:19:40,271 : INFO : EPOCH 1 - PROGRESS: at 24.17% examples, 449767 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:19:41,280 : INFO : EPOCH 1 - PROGRESS: at 24.47% examples, 450018 words/s, in_qsize 19, out_qsize 1
# 2022-05-19 03:19:42,326 : INFO : EPOCH 1 - PROGRESS: at 24.77% examples, 450220 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:19:43,341 : INFO : EPOCH 1 - PROGRESS: at 25.07% examples, 450431 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:19:44,376 : INFO : EPOCH 1 - PROGRESS: at 25.37% examples, 450633 words/s, in_qsize 18, out_qsize 2
# 2022-05-19 03:19:45,379 : INFO : EPOCH 1 - PROGRESS: at 25.69% examples, 451359 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:19:46,421 : INFO : EPOCH 1 - PROGRESS: at 25.98% examples, 451289 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:19:47,439 : INFO : EPOCH 1 - PROGRESS: at 26.29% examples, 451735 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:19:48,449 : INFO : EPOCH 1 - PROGRESS: at 26.55% examples, 451409 words/s, in_qsize 15, out_qsize 5
# 2022-05-19 03:19:49,468 : INFO : EPOCH 1 - PROGRESS: at 26.89% examples, 452365 words/s, in_qsize 14, out_qsize 0
# 2022-05-19 03:19:50,467 : INFO : EPOCH 1 - PROGRESS: at 27.16% examples, 452034 words/s, in_qsize 18, out_qsize 2
# 2022-05-19 03:19:51,527 : INFO : EPOCH 1 - PROGRESS: at 27.47% examples, 452292 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:19:52,537 : INFO : EPOCH 1 - PROGRESS: at 27.76% examples, 452329 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:19:53,580 : INFO : EPOCH 1 - PROGRESS: at 28.05% examples, 452380 words/s, in_qsize 11, out_qsize 8
# 2022-05-19 03:19:54,629 : INFO : EPOCH 1 - PROGRESS: at 28.37% examples, 452690 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:19:55,631 : INFO : EPOCH 1 - PROGRESS: at 28.69% examples, 453394 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:19:56,673 : INFO : EPOCH 1 - PROGRESS: at 28.95% examples, 453000 words/s, in_qsize 20, out_qsize 3
# 2022-05-19 03:19:57,694 : INFO : EPOCH 1 - PROGRESS: at 29.28% examples, 453536 words/s, in_qsize 20, out_qsize 2
# 2022-05-19 03:19:58,711 : INFO : EPOCH 1 - PROGRESS: at 29.59% examples, 453846 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:19:59,755 : INFO : EPOCH 1 - PROGRESS: at 29.87% examples, 453661 words/s, in_qsize 18, out_qsize 5
# 2022-05-19 03:20:00,767 : INFO : EPOCH 1 - PROGRESS: at 30.19% examples, 454093 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:20:01,767 : INFO : EPOCH 1 - PROGRESS: at 30.48% examples, 454279 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:20:02,774 : INFO : EPOCH 1 - PROGRESS: at 30.78% examples, 454443 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:20:03,802 : INFO : EPOCH 1 - PROGRESS: at 31.10% examples, 454952 words/s, in_qsize 12, out_qsize 0
# 2022-05-19 03:20:04,798 : INFO : EPOCH 1 - PROGRESS: at 31.36% examples, 454539 words/s, in_qsize 16, out_qsize 6
# 2022-05-19 03:20:05,849 : INFO : EPOCH 1 - PROGRESS: at 31.67% examples, 454787 words/s, in_qsize 19, out_qsize 2
# 2022-05-19 03:20:06,859 : INFO : EPOCH 1 - PROGRESS: at 31.98% examples, 455036 words/s, in_qsize 19, out_qsize 1
# 2022-05-19 03:20:07,869 : INFO : EPOCH 1 - PROGRESS: at 32.30% examples, 455506 words/s, in_qsize 17, out_qsize 0
# 2022-05-19 03:20:08,922 : INFO : EPOCH 1 - PROGRESS: at 32.58% examples, 455334 words/s, in_qsize 20, out_qsize 2
# 2022-05-19 03:20:09,978 : INFO : EPOCH 1 - PROGRESS: at 32.90% examples, 455610 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:20:10,985 : INFO : EPOCH 1 - PROGRESS: at 33.20% examples, 455853 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:20:12,075 : INFO : EPOCH 1 - PROGRESS: at 33.52% examples, 456048 words/s, in_qsize 17, out_qsize 4
# 2022-05-19 03:20:13,129 : INFO : EPOCH 1 - PROGRESS: at 33.85% examples, 456419 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:20:14,161 : INFO : EPOCH 1 - PROGRESS: at 34.16% examples, 456596 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:20:15,197 : INFO : EPOCH 1 - PROGRESS: at 34.44% examples, 456485 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:20:16,236 : INFO : EPOCH 1 - PROGRESS: at 34.74% examples, 456497 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:20:17,237 : INFO : EPOCH 1 - PROGRESS: at 35.06% examples, 456997 words/s, in_qsize 17, out_qsize 0
# 2022-05-19 03:20:18,282 : INFO : EPOCH 1 - PROGRESS: at 35.34% examples, 456764 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:20:19,309 : INFO : EPOCH 1 - PROGRESS: at 35.65% examples, 456955 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:20:20,318 : INFO : EPOCH 1 - PROGRESS: at 35.95% examples, 457159 words/s, in_qsize 17, out_qsize 2
# 2022-05-19 03:20:21,331 : INFO : EPOCH 1 - PROGRESS: at 36.20% examples, 456745 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:20:22,418 : INFO : EPOCH 1 - PROGRESS: at 36.39% examples, 455221 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:20:23,428 : INFO : EPOCH 1 - PROGRESS: at 36.63% examples, 454614 words/s, in_qsize 19, out_qsize 3
# 2022-05-19 03:20:24,492 : INFO : EPOCH 1 - PROGRESS: at 36.93% examples, 454679 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:20:25,496 : INFO : EPOCH 1 - PROGRESS: at 37.23% examples, 454815 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:20:26,507 : INFO : EPOCH 1 - PROGRESS: at 37.52% examples, 454835 words/s, in_qsize 14, out_qsize 6
# 2022-05-19 03:20:27,585 : INFO : EPOCH 1 - PROGRESS: at 37.83% examples, 454930 words/s, in_qsize 17, out_qsize 2
# 2022-05-19 03:20:28,639 : INFO : EPOCH 1 - PROGRESS: at 38.14% examples, 455070 words/s, in_qsize 12, out_qsize 7
# 2022-05-19 03:20:29,660 : INFO : EPOCH 1 - PROGRESS: at 38.46% examples, 455421 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:20:30,666 : INFO : EPOCH 1 - PROGRESS: at 38.76% examples, 455655 words/s, in_qsize 17, out_qsize 2
# 2022-05-19 03:20:31,705 : INFO : EPOCH 1 - PROGRESS: at 39.05% examples, 455554 words/s, in_qsize 17, out_qsize 2
# 2022-05-19 03:20:32,734 : INFO : EPOCH 1 - PROGRESS: at 39.35% examples, 455596 words/s, in_qsize 16, out_qsize 6
# 2022-05-19 03:20:33,823 : INFO : EPOCH 1 - PROGRESS: at 39.67% examples, 455803 words/s, in_qsize 19, out_qsize 1
# 2022-05-19 03:20:34,835 : INFO : EPOCH 1 - PROGRESS: at 39.98% examples, 456024 words/s, in_qsize 14, out_qsize 4
# 2022-05-19 03:20:35,838 : INFO : EPOCH 1 - PROGRESS: at 40.27% examples, 456110 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:20:36,849 : INFO : EPOCH 1 - PROGRESS: at 40.55% examples, 456076 words/s, in_qsize 18, out_qsize 6
# 2022-05-19 03:20:37,854 : INFO : EPOCH 1 - PROGRESS: at 40.88% examples, 456530 words/s, in_qsize 17, out_qsize 0
# 2022-05-19 03:20:38,869 : INFO : EPOCH 1 - PROGRESS: at 41.15% examples, 456371 words/s, in_qsize 17, out_qsize 5
# 2022-05-19 03:20:39,958 : INFO : EPOCH 1 - PROGRESS: at 41.48% examples, 456568 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:20:40,999 : INFO : EPOCH 1 - PROGRESS: at 41.79% examples, 456727 words/s, in_qsize 20, out_qsize 2
# 2022-05-19 03:20:42,012 : INFO : EPOCH 1 - PROGRESS: at 42.11% examples, 457121 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:20:43,036 : INFO : EPOCH 1 - PROGRESS: at 42.41% examples, 457173 words/s, in_qsize 18, out_qsize 3
# 2022-05-19 03:20:44,038 : INFO : EPOCH 1 - PROGRESS: at 42.72% examples, 457435 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:20:45,125 : INFO : EPOCH 1 - PROGRESS: at 42.99% examples, 457116 words/s, in_qsize 20, out_qsize 10
# 2022-05-19 03:20:46,118 : INFO : EPOCH 1 - PROGRESS: at 43.30% examples, 457371 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:20:47,147 : INFO : EPOCH 1 - PROGRESS: at 43.63% examples, 457733 words/s, in_qsize 18, out_qsize 0
# 2022-05-19 03:20:48,155 : INFO : EPOCH 1 - PROGRESS: at 43.93% examples, 457824 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:20:49,208 : INFO : EPOCH 1 - PROGRESS: at 44.23% examples, 457880 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:20:50,218 : INFO : EPOCH 1 - PROGRESS: at 44.54% examples, 458021 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:20:51,228 : INFO : EPOCH 1 - PROGRESS: at 44.83% examples, 458103 words/s, in_qsize 14, out_qsize 5
# 2022-05-19 03:20:52,250 : INFO : EPOCH 1 - PROGRESS: at 45.15% examples, 458378 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:20:53,308 : INFO : EPOCH 1 - PROGRESS: at 45.44% examples, 458274 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:20:54,368 : INFO : EPOCH 1 - PROGRESS: at 45.76% examples, 458423 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:20:55,382 : INFO : EPOCH 1 - PROGRESS: at 46.06% examples, 458578 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:20:56,386 : INFO : EPOCH 1 - PROGRESS: at 46.36% examples, 458761 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:20:57,394 : INFO : EPOCH 1 - PROGRESS: at 46.67% examples, 458898 words/s, in_qsize 17, out_qsize 0
# 2022-05-19 03:20:58,446 : INFO : EPOCH 1 - PROGRESS: at 46.97% examples, 458900 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:20:59,476 : INFO : EPOCH 1 - PROGRESS: at 47.29% examples, 459269 words/s, in_qsize 17, out_qsize 1
# 2022-05-19 03:21:00,537 : INFO : EPOCH 1 - PROGRESS: at 47.59% examples, 459281 words/s, in_qsize 19, out_qsize 1
# 2022-05-19 03:21:01,566 : INFO : EPOCH 1 - PROGRESS: at 47.89% examples, 459320 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:21:02,619 : INFO : EPOCH 1 - PROGRESS: at 48.21% examples, 459470 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:21:03,630 : INFO : EPOCH 1 - PROGRESS: at 48.52% examples, 459671 words/s, in_qsize 19, out_qsize 1
# 2022-05-19 03:21:04,686 : INFO : EPOCH 1 - PROGRESS: at 48.80% examples, 459504 words/s, in_qsize 15, out_qsize 4
# 2022-05-19 03:21:05,717 : INFO : EPOCH 1 - PROGRESS: at 49.12% examples, 459790 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:21:06,719 : INFO : EPOCH 1 - PROGRESS: at 49.41% examples, 459808 words/s, in_qsize 16, out_qsize 5
# 2022-05-19 03:21:07,728 : INFO : EPOCH 1 - PROGRESS: at 49.72% examples, 459999 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:21:08,742 : INFO : EPOCH 1 - PROGRESS: at 50.01% examples, 459997 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:21:09,769 : INFO : EPOCH 1 - PROGRESS: at 50.32% examples, 460133 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:21:10,784 : INFO : EPOCH 1 - PROGRESS: at 50.61% examples, 460146 words/s, in_qsize 10, out_qsize 9
# 2022-05-19 03:21:11,825 : INFO : EPOCH 1 - PROGRESS: at 50.93% examples, 460295 words/s, in_qsize 18, out_qsize 2
# 2022-05-19 03:21:12,826 : INFO : EPOCH 1 - PROGRESS: at 51.24% examples, 460504 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:21:13,840 : INFO : EPOCH 1 - PROGRESS: at 51.55% examples, 460710 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:21:14,856 : INFO : EPOCH 1 - PROGRESS: at 51.85% examples, 460798 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:21:15,864 : INFO : EPOCH 1 - PROGRESS: at 52.15% examples, 460901 words/s, in_qsize 18, out_qsize 0
# 2022-05-19 03:21:16,885 : INFO : EPOCH 1 - PROGRESS: at 52.44% examples, 460894 words/s, in_qsize 18, out_qsize 3
# 2022-05-19 03:21:17,916 : INFO : EPOCH 1 - PROGRESS: at 52.72% examples, 460777 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:21:18,933 : INFO : EPOCH 1 - PROGRESS: at 53.05% examples, 461056 words/s, in_qsize 20, out_qsize 1
# 2022-05-19 03:21:19,949 : INFO : EPOCH 1 - PROGRESS: at 53.33% examples, 460956 words/s, in_qsize 16, out_qsize 8
# 2022-05-19 03:21:20,952 : INFO : EPOCH 1 - PROGRESS: at 53.64% examples, 461227 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:21:21,959 : INFO : EPOCH 1 - PROGRESS: at 53.93% examples, 461182 words/s, in_qsize 18, out_qsize 0
# 2022-05-19 03:21:22,970 : INFO : EPOCH 1 - PROGRESS: at 54.21% examples, 461152 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:21:23,976 : INFO : EPOCH 1 - PROGRESS: at 54.51% examples, 461182 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:21:24,995 : INFO : EPOCH 1 - PROGRESS: at 54.80% examples, 461190 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:21:26,015 : INFO : EPOCH 1 - PROGRESS: at 55.08% examples, 461158 words/s, in_qsize 18, out_qsize 4
# 2022-05-19 03:21:27,043 : INFO : EPOCH 1 - PROGRESS: at 55.41% examples, 461437 words/s, in_qsize 17, out_qsize 0
# 2022-05-19 03:21:28,108 : INFO : EPOCH 1 - PROGRESS: at 55.70% examples, 461284 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:21:29,143 : INFO : EPOCH 1 - PROGRESS: at 56.01% examples, 461389 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:21:30,144 : INFO : EPOCH 1 - PROGRESS: at 56.31% examples, 461500 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:21:31,153 : INFO : EPOCH 1 - PROGRESS: at 56.60% examples, 461561 words/s, in_qsize 17, out_qsize 2
# 2022-05-19 03:21:32,214 : INFO : EPOCH 1 - PROGRESS: at 56.85% examples, 461098 words/s, in_qsize 17, out_qsize 2
# 2022-05-19 03:21:33,226 : INFO : EPOCH 1 - PROGRESS: at 57.07% examples, 460493 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:21:34,236 : INFO : EPOCH 1 - PROGRESS: at 57.29% examples, 459975 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:21:35,262 : INFO : EPOCH 1 - PROGRESS: at 57.51% examples, 459385 words/s, in_qsize 19, out_qsize 3
# 2022-05-19 03:21:36,315 : INFO : EPOCH 1 - PROGRESS: at 57.74% examples, 458816 words/s, in_qsize 18, out_qsize 4
# 2022-05-19 03:21:37,402 : INFO : EPOCH 1 - PROGRESS: at 57.99% examples, 458314 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:21:38,439 : INFO : EPOCH 1 - PROGRESS: at 58.21% examples, 457764 words/s, in_qsize 20, out_qsize 1
# 2022-05-19 03:21:39,526 : INFO : EPOCH 1 - PROGRESS: at 58.43% examples, 457063 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:21:40,536 : INFO : EPOCH 1 - PROGRESS: at 58.64% examples, 456504 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:21:41,555 : INFO : EPOCH 1 - PROGRESS: at 58.88% examples, 456067 words/s, in_qsize 18, out_qsize 0
# 2022-05-19 03:21:42,613 : INFO : EPOCH 1 - PROGRESS: at 59.10% examples, 455486 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:21:43,619 : INFO : EPOCH 1 - PROGRESS: at 59.31% examples, 454935 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:21:44,702 : INFO : EPOCH 1 - PROGRESS: at 59.56% examples, 454504 words/s, in_qsize 19, out_qsize 1
# 2022-05-19 03:21:45,723 : INFO : EPOCH 1 - PROGRESS: at 59.76% examples, 453887 words/s, in_qsize 16, out_qsize 8
# 2022-05-19 03:21:46,744 : INFO : EPOCH 1 - PROGRESS: at 60.08% examples, 454023 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:21:47,762 : INFO : EPOCH 1 - PROGRESS: at 60.38% examples, 454119 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:21:48,776 : INFO : EPOCH 1 - PROGRESS: at 60.69% examples, 454280 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:21:49,783 : INFO : EPOCH 1 - PROGRESS: at 60.98% examples, 454366 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:21:50,832 : INFO : EPOCH 1 - PROGRESS: at 61.28% examples, 454390 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:21:51,843 : INFO : EPOCH 1 - PROGRESS: at 61.58% examples, 454508 words/s, in_qsize 18, out_qsize 2
# 2022-05-19 03:21:52,848 : INFO : EPOCH 1 - PROGRESS: at 61.88% examples, 454632 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:21:53,951 : INFO : EPOCH 1 - PROGRESS: at 62.20% examples, 454736 words/s, in_qsize 19, out_qsize 1
# 2022-05-19 03:21:54,971 : INFO : EPOCH 1 - PROGRESS: at 62.49% examples, 454739 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:21:55,996 : INFO : EPOCH 1 - PROGRESS: at 62.79% examples, 454785 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:21:57,004 : INFO : EPOCH 1 - PROGRESS: at 63.11% examples, 455054 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:21:58,029 : INFO : EPOCH 1 - PROGRESS: at 63.42% examples, 455148 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:21:59,070 : INFO : EPOCH 1 - PROGRESS: at 63.71% examples, 455165 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:22:00,081 : INFO : EPOCH 1 - PROGRESS: at 64.01% examples, 455267 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:22:01,087 : INFO : EPOCH 1 - PROGRESS: at 64.29% examples, 455222 words/s, in_qsize 19, out_qsize 1
# 2022-05-19 03:22:02,132 : INFO : EPOCH 1 - PROGRESS: at 64.60% examples, 455290 words/s, in_qsize 16, out_qsize 3
# 2022-05-19 03:22:03,200 : INFO : EPOCH 1 - PROGRESS: at 64.91% examples, 455440 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:22:04,216 : INFO : EPOCH 1 - PROGRESS: at 65.21% examples, 455419 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:22:05,310 : INFO : EPOCH 1 - PROGRESS: at 65.52% examples, 455440 words/s, in_qsize 15, out_qsize 4
# 2022-05-19 03:22:06,336 : INFO : EPOCH 1 - PROGRESS: at 65.85% examples, 455703 words/s, in_qsize 18, out_qsize 0
# 2022-05-19 03:22:07,401 : INFO : EPOCH 1 - PROGRESS: at 66.14% examples, 455663 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:22:08,438 : INFO : EPOCH 1 - PROGRESS: at 66.47% examples, 455858 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:22:09,447 : INFO : EPOCH 1 - PROGRESS: at 66.77% examples, 455982 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:22:10,533 : INFO : EPOCH 1 - PROGRESS: at 67.06% examples, 455873 words/s, in_qsize 16, out_qsize 3
# 2022-05-19 03:22:11,605 : INFO : EPOCH 1 - PROGRESS: at 67.39% examples, 456007 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:22:12,657 : INFO : EPOCH 1 - PROGRESS: at 67.70% examples, 456136 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:22:13,663 : INFO : EPOCH 1 - PROGRESS: at 68.02% examples, 456353 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:22:14,667 : INFO : EPOCH 1 - PROGRESS: at 68.31% examples, 456393 words/s, in_qsize 17, out_qsize 0
# 2022-05-19 03:22:15,685 : INFO : EPOCH 1 - PROGRESS: at 68.61% examples, 456441 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:22:16,728 : INFO : EPOCH 1 - PROGRESS: at 68.91% examples, 456468 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:22:17,793 : INFO : EPOCH 1 - PROGRESS: at 69.22% examples, 456520 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:22:18,810 : INFO : EPOCH 1 - PROGRESS: at 69.52% examples, 456594 words/s, in_qsize 14, out_qsize 5
# 2022-05-19 03:22:19,812 : INFO : EPOCH 1 - PROGRESS: at 69.84% examples, 456820 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:22:20,846 : INFO : EPOCH 1 - PROGRESS: at 70.12% examples, 456738 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:22:21,846 : INFO : EPOCH 1 - PROGRESS: at 70.44% examples, 456962 words/s, in_qsize 19, out_qsize 1
# 2022-05-19 03:22:22,892 : INFO : EPOCH 1 - PROGRESS: at 70.71% examples, 456856 words/s, in_qsize 19, out_qsize 2
# 2022-05-19 03:22:23,902 : INFO : EPOCH 1 - PROGRESS: at 71.05% examples, 457113 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:22:24,944 : INFO : EPOCH 1 - PROGRESS: at 71.33% examples, 457055 words/s, in_qsize 18, out_qsize 2
# 2022-05-19 03:22:26,001 : INFO : EPOCH 1 - PROGRESS: at 71.64% examples, 457076 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:22:27,021 : INFO : EPOCH 1 - PROGRESS: at 71.94% examples, 457145 words/s, in_qsize 15, out_qsize 4
# 2022-05-19 03:22:28,108 : INFO : EPOCH 1 - PROGRESS: at 72.26% examples, 457202 words/s, in_qsize 15, out_qsize 7
# 2022-05-19 03:22:29,196 : INFO : EPOCH 1 - PROGRESS: at 72.59% examples, 457374 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:22:30,196 : INFO : EPOCH 1 - PROGRESS: at 72.90% examples, 457536 words/s, in_qsize 17, out_qsize 1
# 2022-05-19 03:22:31,309 : INFO : EPOCH 1 - PROGRESS: at 73.20% examples, 457425 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:22:32,336 : INFO : EPOCH 1 - PROGRESS: at 73.53% examples, 457619 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:22:33,350 : INFO : EPOCH 1 - PROGRESS: at 73.82% examples, 457672 words/s, in_qsize 19, out_qsize 1
# 2022-05-19 03:22:34,413 : INFO : EPOCH 1 - PROGRESS: at 74.12% examples, 457665 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:22:35,421 : INFO : EPOCH 1 - PROGRESS: at 74.44% examples, 457832 words/s, in_qsize 16, out_qsize 0
# 2022-05-19 03:22:36,429 : INFO : EPOCH 1 - PROGRESS: at 74.71% examples, 457774 words/s, in_qsize 20, out_qsize 3
# 2022-05-19 03:22:37,507 : INFO : EPOCH 1 - PROGRESS: at 75.03% examples, 457813 words/s, in_qsize 17, out_qsize 2
# 2022-05-19 03:22:38,513 : INFO : EPOCH 1 - PROGRESS: at 75.35% examples, 458033 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:22:39,567 : INFO : EPOCH 1 - PROGRESS: at 75.65% examples, 458020 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:22:40,573 : INFO : EPOCH 1 - PROGRESS: at 75.95% examples, 458136 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:22:41,593 : INFO : EPOCH 1 - PROGRESS: at 76.26% examples, 458248 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:22:42,627 : INFO : EPOCH 1 - PROGRESS: at 76.56% examples, 458290 words/s, in_qsize 15, out_qsize 4
# 2022-05-19 03:22:43,639 : INFO : EPOCH 1 - PROGRESS: at 76.84% examples, 458234 words/s, in_qsize 16, out_qsize 3
# 2022-05-19 03:22:44,680 : INFO : EPOCH 1 - PROGRESS: at 77.16% examples, 458389 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:22:45,709 : INFO : EPOCH 1 - PROGRESS: at 77.46% examples, 458426 words/s, in_qsize 19, out_qsize 3
# 2022-05-19 03:22:46,710 : INFO : EPOCH 1 - PROGRESS: at 77.78% examples, 458626 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:22:47,712 : INFO : EPOCH 1 - PROGRESS: at 78.06% examples, 458561 words/s, in_qsize 16, out_qsize 4
# 2022-05-19 03:22:48,726 : INFO : EPOCH 1 - PROGRESS: at 78.36% examples, 458680 words/s, in_qsize 19, out_qsize 1
# 2022-05-19 03:22:49,739 : INFO : EPOCH 1 - PROGRESS: at 78.65% examples, 458669 words/s, in_qsize 19, out_qsize 6
# 2022-05-19 03:22:50,735 : INFO : EPOCH 1 - PROGRESS: at 78.96% examples, 458797 words/s, in_qsize 19, out_qsize 1
# 2022-05-19 03:22:51,749 : INFO : EPOCH 1 - PROGRESS: at 79.24% examples, 458785 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:22:52,756 : INFO : EPOCH 1 - PROGRESS: at 79.54% examples, 458834 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:22:53,778 : INFO : EPOCH 1 - PROGRESS: at 79.86% examples, 458990 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:22:54,833 : INFO : EPOCH 1 - PROGRESS: at 80.15% examples, 458933 words/s, in_qsize 15, out_qsize 6
# 2022-05-19 03:22:55,870 : INFO : EPOCH 1 - PROGRESS: at 80.46% examples, 459046 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:22:56,877 : INFO : EPOCH 1 - PROGRESS: at 80.77% examples, 459139 words/s, in_qsize 16, out_qsize 3
# 2022-05-19 03:22:57,923 : INFO : EPOCH 1 - PROGRESS: at 81.08% examples, 459213 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:22:58,954 : INFO : EPOCH 1 - PROGRESS: at 81.38% examples, 459254 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:22:59,955 : INFO : EPOCH 1 - PROGRESS: at 81.70% examples, 459456 words/s, in_qsize 19, out_qsize 1
# 2022-05-19 03:23:00,996 : INFO : EPOCH 1 - PROGRESS: at 81.99% examples, 459429 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:23:02,001 : INFO : EPOCH 1 - PROGRESS: at 82.30% examples, 459558 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:23:03,040 : INFO : EPOCH 1 - PROGRESS: at 82.57% examples, 459385 words/s, in_qsize 17, out_qsize 4
# 2022-05-19 03:23:04,040 : INFO : EPOCH 1 - PROGRESS: at 82.88% examples, 459541 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:23:05,070 : INFO : EPOCH 1 - PROGRESS: at 83.18% examples, 459575 words/s, in_qsize 17, out_qsize 2
# 2022-05-19 03:23:06,080 : INFO : EPOCH 1 - PROGRESS: at 83.49% examples, 459676 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:23:07,165 : INFO : EPOCH 1 - PROGRESS: at 83.79% examples, 459626 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:23:08,167 : INFO : EPOCH 1 - PROGRESS: at 84.09% examples, 459731 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:23:09,197 : INFO : EPOCH 1 - PROGRESS: at 84.38% examples, 459695 words/s, in_qsize 17, out_qsize 2
# 2022-05-19 03:23:10,210 : INFO : EPOCH 1 - PROGRESS: at 84.69% examples, 459828 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:23:11,278 : INFO : EPOCH 1 - PROGRESS: at 84.99% examples, 459830 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:23:12,300 : INFO : EPOCH 1 - PROGRESS: at 85.29% examples, 459817 words/s, in_qsize 15, out_qsize 4
# 2022-05-19 03:23:13,301 : INFO : EPOCH 1 - PROGRESS: at 85.61% examples, 459987 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:23:14,304 : INFO : EPOCH 1 - PROGRESS: at 85.89% examples, 459963 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:23:15,317 : INFO : EPOCH 1 - PROGRESS: at 86.19% examples, 460032 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:23:16,350 : INFO : EPOCH 1 - PROGRESS: at 86.51% examples, 460179 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:23:17,416 : INFO : EPOCH 1 - PROGRESS: at 86.80% examples, 460078 words/s, in_qsize 19, out_qsize 4
# 2022-05-19 03:23:18,407 : INFO : EPOCH 1 - PROGRESS: at 87.10% examples, 460168 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:23:19,435 : INFO : EPOCH 1 - PROGRESS: at 87.40% examples, 460204 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:23:20,459 : INFO : EPOCH 1 - PROGRESS: at 87.70% examples, 460225 words/s, in_qsize 19, out_qsize 1
# 2022-05-19 03:23:21,476 : INFO : EPOCH 1 - PROGRESS: at 88.02% examples, 460395 words/s, in_qsize 17, out_qsize 1
# 2022-05-19 03:23:22,515 : INFO : EPOCH 1 - PROGRESS: at 88.29% examples, 460253 words/s, in_qsize 19, out_qsize 1
# 2022-05-19 03:23:23,532 : INFO : EPOCH 1 - PROGRESS: at 88.59% examples, 460329 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:23:24,534 : INFO : EPOCH 1 - PROGRESS: at 88.90% examples, 460393 words/s, in_qsize 17, out_qsize 2
# 2022-05-19 03:23:25,635 : INFO : EPOCH 1 - PROGRESS: at 89.21% examples, 460419 words/s, in_qsize 19, out_qsize 1
# 2022-05-19 03:23:26,634 : INFO : EPOCH 1 - PROGRESS: at 89.53% examples, 460565 words/s, in_qsize 17, out_qsize 0
# 2022-05-19 03:23:27,675 : INFO : EPOCH 1 - PROGRESS: at 89.82% examples, 460531 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:23:28,684 : INFO : EPOCH 1 - PROGRESS: at 90.14% examples, 460706 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:23:29,708 : INFO : EPOCH 1 - PROGRESS: at 90.43% examples, 460692 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:23:30,756 : INFO : EPOCH 1 - PROGRESS: at 90.73% examples, 460667 words/s, in_qsize 20, out_qsize 1
# 2022-05-19 03:23:31,756 : INFO : EPOCH 1 - PROGRESS: at 91.03% examples, 460760 words/s, in_qsize 18, out_qsize 2
# 2022-05-19 03:23:32,770 : INFO : EPOCH 1 - PROGRESS: at 91.34% examples, 460854 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:23:33,865 : INFO : EPOCH 1 - PROGRESS: at 91.64% examples, 460741 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:23:34,867 : INFO : EPOCH 1 - PROGRESS: at 91.93% examples, 460784 words/s, in_qsize 17, out_qsize 1
# 2022-05-19 03:23:35,890 : INFO : EPOCH 1 - PROGRESS: at 92.24% examples, 460846 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:23:36,908 : INFO : EPOCH 1 - PROGRESS: at 92.54% examples, 460890 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:23:37,953 : INFO : EPOCH 1 - PROGRESS: at 92.85% examples, 460941 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:23:38,995 : INFO : EPOCH 1 - PROGRESS: at 93.15% examples, 460968 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:23:40,067 : INFO : EPOCH 1 - PROGRESS: at 93.47% examples, 461022 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:23:41,087 : INFO : EPOCH 1 - PROGRESS: at 93.77% examples, 461044 words/s, in_qsize 18, out_qsize 3
# 2022-05-19 03:23:42,138 : INFO : EPOCH 1 - PROGRESS: at 94.09% examples, 461172 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:23:43,173 : INFO : EPOCH 1 - PROGRESS: at 94.39% examples, 461167 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:23:44,269 : INFO : EPOCH 1 - PROGRESS: at 94.70% examples, 461178 words/s, in_qsize 19, out_qsize 5
# 2022-05-19 03:23:45,346 : INFO : EPOCH 1 - PROGRESS: at 95.02% examples, 461186 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:23:46,353 : INFO : EPOCH 1 - PROGRESS: at 95.34% examples, 461353 words/s, in_qsize 17, out_qsize 0
# 2022-05-19 03:23:47,409 : INFO : EPOCH 1 - PROGRESS: at 95.62% examples, 461264 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:23:48,424 : INFO : EPOCH 1 - PROGRESS: at 95.92% examples, 461308 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:23:49,436 : INFO : EPOCH 1 - PROGRESS: at 96.22% examples, 461333 words/s, in_qsize 17, out_qsize 2
# 2022-05-19 03:23:50,475 : INFO : EPOCH 1 - PROGRESS: at 96.52% examples, 461348 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:23:51,479 : INFO : EPOCH 1 - PROGRESS: at 96.81% examples, 461360 words/s, in_qsize 19, out_qsize 1
# 2022-05-19 03:23:52,480 : INFO : EPOCH 1 - PROGRESS: at 97.11% examples, 461419 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:23:53,495 : INFO : EPOCH 1 - PROGRESS: at 97.43% examples, 461528 words/s, in_qsize 19, out_qsize 1
# 2022-05-19 03:23:54,519 : INFO : EPOCH 1 - PROGRESS: at 97.74% examples, 461608 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:23:55,547 : INFO : EPOCH 1 - PROGRESS: at 98.01% examples, 461504 words/s, in_qsize 19, out_qsize 2
# 2022-05-19 03:23:56,591 : INFO : EPOCH 1 - PROGRESS: at 98.32% examples, 461541 words/s, in_qsize 13, out_qsize 6
# 2022-05-19 03:23:57,592 : INFO : EPOCH 1 - PROGRESS: at 98.61% examples, 461590 words/s, in_qsize 17, out_qsize 2
# 2022-05-19 03:23:58,598 : INFO : EPOCH 1 - PROGRESS: at 98.92% examples, 461692 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:23:59,701 : INFO : EPOCH 1 - PROGRESS: at 99.24% examples, 461702 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:24:00,704 : INFO : EPOCH 1 - PROGRESS: at 99.56% examples, 461858 words/s, in_qsize 17, out_qsize 0
# 2022-05-19 03:24:01,727 : INFO : EPOCH 1 - PROGRESS: at 99.79% examples, 461559 words/s, in_qsize 19, out_qsize 1
# 2022-05-19 03:24:02,396 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2022-05-19 03:24:02,420 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2022-05-19 03:24:02,479 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2022-05-19 03:24:02,524 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2022-05-19 03:24:02,538 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2022-05-19 03:24:02,551 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2022-05-19 03:24:02,575 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2022-05-19 03:24:02,584 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-05-19 03:24:02,588 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-05-19 03:24:02,596 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-05-19 03:24:02,599 : INFO : EPOCH - 1 : training on 222967702 raw words (160919698 effective words) took 348.8s, 461352 effective words/s
# 2022-05-19 03:24:03,658 : INFO : EPOCH 2 - PROGRESS: at 0.13% examples, 209961 words/s, in_qsize 17, out_qsize 2
# 2022-05-19 03:24:04,664 : INFO : EPOCH 2 - PROGRESS: at 0.38% examples, 301109 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:24:05,667 : INFO : EPOCH 2 - PROGRESS: at 0.59% examples, 314849 words/s, in_qsize 17, out_qsize 0
# 2022-05-19 03:24:06,697 : INFO : EPOCH 2 - PROGRESS: at 0.83% examples, 329421 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:24:07,771 : INFO : EPOCH 2 - PROGRESS: at 1.07% examples, 335332 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:24:08,825 : INFO : EPOCH 2 - PROGRESS: at 1.32% examples, 343889 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:24:09,829 : INFO : EPOCH 2 - PROGRESS: at 1.55% examples, 347089 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:24:10,882 : INFO : EPOCH 2 - PROGRESS: at 1.82% examples, 354536 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:24:11,982 : INFO : EPOCH 2 - PROGRESS: at 2.03% examples, 349721 words/s, in_qsize 12, out_qsize 7
# 2022-05-19 03:24:13,023 : INFO : EPOCH 2 - PROGRESS: at 2.26% examples, 350178 words/s, in_qsize 13, out_qsize 8
# 2022-05-19 03:24:14,083 : INFO : EPOCH 2 - PROGRESS: at 2.52% examples, 354512 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:24:15,110 : INFO : EPOCH 2 - PROGRESS: at 2.75% examples, 355362 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:24:16,159 : INFO : EPOCH 2 - PROGRESS: at 2.99% examples, 355941 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:24:17,271 : INFO : EPOCH 2 - PROGRESS: at 3.29% examples, 361960 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:24:18,275 : INFO : EPOCH 2 - PROGRESS: at 3.59% examples, 369727 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:24:19,286 : INFO : EPOCH 2 - PROGRESS: at 3.91% examples, 377603 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:24:20,341 : INFO : EPOCH 2 - PROGRESS: at 4.20% examples, 381797 words/s, in_qsize 19, out_qsize 1
# 2022-05-19 03:24:21,342 : INFO : EPOCH 2 - PROGRESS: at 4.49% examples, 386168 words/s, in_qsize 19, out_qsize 2
# 2022-05-19 03:24:22,347 : INFO : EPOCH 2 - PROGRESS: at 4.81% examples, 392795 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 03:24:23,372 : INFO : EPOCH 2 - PROGRESS: at 5.09% examples, 394904 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:24:24,376 : INFO : EPOCH 2 - PROGRESS: at 5.36% examples, 396539 words/s, in_qsize 16, out_qsize 4
# 2022-05-19 03:24:25,383 : INFO : EPOCH 2 - PROGRESS: at 5.67% examples, 400825 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:24:26,423 : INFO : EPOCH 2 - PROGRESS: at 5.96% examples, 403464 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:24:27,428 : INFO : EPOCH 2 - PROGRESS: at 6.27% examples, 407193 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:24:28,448 : INFO : EPOCH 2 - PROGRESS: at 6.55% examples, 408432 words/s, in_qsize 17, out_qsize 2
# 2022-05-19 03:24:29,511 : INFO : EPOCH 2 - PROGRESS: at 6.85% examples, 410259 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:24:30,539 : INFO : EPOCH 2 - PROGRESS: at 7.16% examples, 412693 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:24:31,548 : INFO : EPOCH 2 - PROGRESS: at 7.47% examples, 415562 words/s, in_qsize 17, out_qsize 0
# 2022-05-19 03:24:32,645 : INFO : EPOCH 2 - PROGRESS: at 7.77% examples, 416444 words/s, in_qsize 17, out_qsize 2
# 2022-05-19 03:24:33,645 : INFO : EPOCH 2 - PROGRESS: at 8.08% examples, 419234 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:24:34,652 : INFO : EPOCH 2 - PROGRESS: at 8.38% examples, 420812 words/s, in_qsize 19, out_qsize 2
# 2022-05-19 03:24:35,732 : INFO : EPOCH 2 - PROGRESS: at 8.67% examples, 421478 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:24:36,774 : INFO : EPOCH 2 - PROGRESS: at 8.99% examples, 423461 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:24:37,820 : INFO : EPOCH 2 - PROGRESS: at 9.27% examples, 424010 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:24:38,852 : INFO : EPOCH 2 - PROGRESS: at 9.58% examples, 425460 words/s, in_qsize 20, out_qsize 1
# 2022-05-19 03:24:39,859 : INFO : EPOCH 2 - PROGRESS: at 9.87% examples, 426528 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:24:40,886 : INFO : EPOCH 2 - PROGRESS: at 10.20% examples, 428752 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:24:41,943 : INFO : EPOCH 2 - PROGRESS: at 10.46% examples, 427930 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:24:42,955 : INFO : EPOCH 2 - PROGRESS: at 10.74% examples, 428480 words/s, in_qsize 17, out_qsize 2
# 2022-05-19 03:24:43,991 : INFO : EPOCH 2 - PROGRESS: at 11.03% examples, 428873 words/s, in_qsize 12, out_qsize 7
# 2022-05-19 03:24:44,992 : INFO : EPOCH 2 - PROGRESS: at 11.35% examples, 431070 words/s, in_qsize 16, out_qsize 2
# 2022-05-19 03:24:45,997 : INFO : EPOCH 2 - PROGRESS: at 11.66% examples, 432524 words/s, in_qsize 12, out_qsize 0
# 2022-05-19 03:24:47,070 : INFO : EPOCH 2 - PROGRESS: at 11.94% examples, 432282 words/s, in_qsize 17, out_qsize 2
# 2022-05-19 03:24:48,105 : INFO : EPOCH 2 - PROGRESS: at 12.24% examples, 432943 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 03:24:49,130 : INFO : EPOCH 2 - PROGRESS: at 12.54% examples, 433948 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:24:50,140 : INFO : EPOCH 2 - PROGRESS: at 12.85% examples, 435023 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 03:24:51,161 : INFO : EPOCH 2 - PROGRESS: at 13.14% examples, 435361 words/s, in_qsize 15, out_qsize 6
# 2022-05-19 03:24:52,199 : INFO : EPOCH 2 - PROGRESS: at 13.45% examples, 436420 words/s, in_qsize 19, out_qsize 3
# 2022-05-19 03:24:53,188 : INFO : EPOCH 2 - PROGRESS: at 13.76% examples, 437607 words/s, in_qsize 19, out_qsize 0
# ...
# 2022-05-19 04:15:05,303 : INFO : EPOCH 10 - PROGRESS: at 65.86% examples, 445676 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:15:06,322 : INFO : EPOCH 10 - PROGRESS: at 66.14% examples, 445679 words/s, in_qsize 18, out_qsize 8
# 2022-05-19 04:15:07,333 : INFO : EPOCH 10 - PROGRESS: at 66.47% examples, 445952 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:15:08,354 : INFO : EPOCH 10 - PROGRESS: at 66.75% examples, 445977 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:15:09,357 : INFO : EPOCH 10 - PROGRESS: at 67.05% examples, 446126 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:15:10,358 : INFO : EPOCH 10 - PROGRESS: at 67.34% examples, 446162 words/s, in_qsize 14, out_qsize 0
# 2022-05-19 04:15:11,414 : INFO : EPOCH 10 - PROGRESS: at 67.63% examples, 446147 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:15:12,470 : INFO : EPOCH 10 - PROGRESS: at 67.93% examples, 446226 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:15:13,498 : INFO : EPOCH 10 - PROGRESS: at 68.22% examples, 446230 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 04:15:14,528 : INFO : EPOCH 10 - PROGRESS: at 68.52% examples, 446296 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 04:15:15,533 : INFO : EPOCH 10 - PROGRESS: at 68.81% examples, 446409 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:15:16,559 : INFO : EPOCH 10 - PROGRESS: at 69.13% examples, 446598 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:15:17,577 : INFO : EPOCH 10 - PROGRESS: at 69.39% examples, 446504 words/s, in_qsize 19, out_qsize 1
# 2022-05-19 04:15:18,579 : INFO : EPOCH 10 - PROGRESS: at 69.70% examples, 446656 words/s, in_qsize 16, out_qsize 2
# 2022-05-19 04:15:19,623 : INFO : EPOCH 10 - PROGRESS: at 70.00% examples, 446770 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:15:20,641 : INFO : EPOCH 10 - PROGRESS: at 70.31% examples, 446886 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:15:21,697 : INFO : EPOCH 10 - PROGRESS: at 70.61% examples, 446992 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:15:22,737 : INFO : EPOCH 10 - PROGRESS: at 70.91% examples, 447038 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:15:23,757 : INFO : EPOCH 10 - PROGRESS: at 71.21% examples, 447125 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 04:15:24,763 : INFO : EPOCH 10 - PROGRESS: at 71.49% examples, 447166 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 04:15:25,777 : INFO : EPOCH 10 - PROGRESS: at 71.80% examples, 447332 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:15:26,804 : INFO : EPOCH 10 - PROGRESS: at 72.08% examples, 447258 words/s, in_qsize 15, out_qsize 5
# 2022-05-19 04:15:27,804 : INFO : EPOCH 10 - PROGRESS: at 72.40% examples, 447560 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:15:28,897 : INFO : EPOCH 10 - PROGRESS: at 72.69% examples, 447458 words/s, in_qsize 17, out_qsize 3
# 2022-05-19 04:15:29,949 : INFO : EPOCH 10 - PROGRESS: at 73.01% examples, 447653 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:15:30,943 : INFO : EPOCH 10 - PROGRESS: at 73.30% examples, 447674 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:15:31,945 : INFO : EPOCH 10 - PROGRESS: at 73.59% examples, 447755 words/s, in_qsize 16, out_qsize 3
# 2022-05-19 04:15:33,004 : INFO : EPOCH 10 - PROGRESS: at 73.88% examples, 447769 words/s, in_qsize 10, out_qsize 9
# 2022-05-19 04:15:34,022 : INFO : EPOCH 10 - PROGRESS: at 74.18% examples, 447870 words/s, in_qsize 20, out_qsize 1
# 2022-05-19 04:15:35,036 : INFO : EPOCH 10 - PROGRESS: at 74.47% examples, 447874 words/s, in_qsize 18, out_qsize 5
# 2022-05-19 04:15:36,040 : INFO : EPOCH 10 - PROGRESS: at 74.79% examples, 448102 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:15:37,051 : INFO : EPOCH 10 - PROGRESS: at 75.07% examples, 448130 words/s, in_qsize 20, out_qsize 2
# 2022-05-19 04:15:38,075 : INFO : EPOCH 10 - PROGRESS: at 75.35% examples, 448085 words/s, in_qsize 20, out_qsize 3
# 2022-05-19 04:15:39,169 : INFO : EPOCH 10 - PROGRESS: at 75.67% examples, 448178 words/s, in_qsize 20, out_qsize 1
# 2022-05-19 04:15:40,199 : INFO : EPOCH 10 - PROGRESS: at 75.97% examples, 448237 words/s, in_qsize 17, out_qsize 2
# 2022-05-19 04:15:41,216 : INFO : EPOCH 10 - PROGRESS: at 76.27% examples, 448335 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:15:42,231 : INFO : EPOCH 10 - PROGRESS: at 76.56% examples, 448389 words/s, in_qsize 19, out_qsize 2
# 2022-05-19 04:15:43,302 : INFO : EPOCH 10 - PROGRESS: at 76.87% examples, 448482 words/s, in_qsize 17, out_qsize 2
# 2022-05-19 04:15:44,309 : INFO : EPOCH 10 - PROGRESS: at 77.16% examples, 448542 words/s, in_qsize 19, out_qsize 3
# 2022-05-19 04:15:45,351 : INFO : EPOCH 10 - PROGRESS: at 77.46% examples, 448575 words/s, in_qsize 17, out_qsize 4
# 2022-05-19 04:15:46,404 : INFO : EPOCH 10 - PROGRESS: at 77.77% examples, 448662 words/s, in_qsize 20, out_qsize 2
# 2022-05-19 04:15:47,451 : INFO : EPOCH 10 - PROGRESS: at 78.07% examples, 448719 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:15:48,465 : INFO : EPOCH 10 - PROGRESS: at 78.37% examples, 448819 words/s, in_qsize 17, out_qsize 2
# 2022-05-19 04:15:49,468 : INFO : EPOCH 10 - PROGRESS: at 78.68% examples, 448995 words/s, in_qsize 17, out_qsize 0
# 2022-05-19 04:15:50,490 : INFO : EPOCH 10 - PROGRESS: at 78.95% examples, 448926 words/s, in_qsize 19, out_qsize 1
# 2022-05-19 04:15:51,558 : INFO : EPOCH 10 - PROGRESS: at 79.26% examples, 448992 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 04:15:52,585 : INFO : EPOCH 10 - PROGRESS: at 79.58% examples, 449143 words/s, in_qsize 20, out_qsize 1
# 2022-05-19 04:15:53,623 : INFO : EPOCH 10 - PROGRESS: at 79.86% examples, 449128 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 04:15:54,639 : INFO : EPOCH 10 - PROGRESS: at 80.15% examples, 449118 words/s, in_qsize 18, out_qsize 2
# 2022-05-19 04:15:55,674 : INFO : EPOCH 10 - PROGRESS: at 80.45% examples, 449192 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 04:15:56,690 : INFO : EPOCH 10 - PROGRESS: at 80.74% examples, 449254 words/s, in_qsize 19, out_qsize 2
# 2022-05-19 04:15:57,754 : INFO : EPOCH 10 - PROGRESS: at 81.04% examples, 449261 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 04:15:58,760 : INFO : EPOCH 10 - PROGRESS: at 81.34% examples, 449348 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:15:59,782 : INFO : EPOCH 10 - PROGRESS: at 81.63% examples, 449399 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:16:00,807 : INFO : EPOCH 10 - PROGRESS: at 81.92% examples, 449431 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:16:01,871 : INFO : EPOCH 10 - PROGRESS: at 82.22% examples, 449454 words/s, in_qsize 17, out_qsize 3
# 2022-05-19 04:16:02,891 : INFO : EPOCH 10 - PROGRESS: at 82.52% examples, 449517 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 04:16:03,891 : INFO : EPOCH 10 - PROGRESS: at 82.83% examples, 449683 words/s, in_qsize 18, out_qsize 0
# 2022-05-19 04:16:04,932 : INFO : EPOCH 10 - PROGRESS: at 83.10% examples, 449589 words/s, in_qsize 17, out_qsize 2
# 2022-05-19 04:16:05,956 : INFO : EPOCH 10 - PROGRESS: at 83.40% examples, 449678 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:16:07,038 : INFO : EPOCH 10 - PROGRESS: at 83.70% examples, 449644 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 04:16:08,103 : INFO : EPOCH 10 - PROGRESS: at 84.01% examples, 449712 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 04:16:09,116 : INFO : EPOCH 10 - PROGRESS: at 84.31% examples, 449809 words/s, in_qsize 18, out_qsize 2
# 2022-05-19 04:16:10,148 : INFO : EPOCH 10 - PROGRESS: at 84.62% examples, 449919 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:16:11,219 : INFO : EPOCH 10 - PROGRESS: at 84.91% examples, 449901 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 04:16:12,259 : INFO : EPOCH 10 - PROGRESS: at 85.22% examples, 449972 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:16:13,280 : INFO : EPOCH 10 - PROGRESS: at 85.50% examples, 449953 words/s, in_qsize 16, out_qsize 3
# 2022-05-19 04:16:14,350 : INFO : EPOCH 10 - PROGRESS: at 85.82% examples, 450070 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:16:15,356 : INFO : EPOCH 10 - PROGRESS: at 86.11% examples, 450135 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:16:16,387 : INFO : EPOCH 10 - PROGRESS: at 86.42% examples, 450199 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 04:16:17,398 : INFO : EPOCH 10 - PROGRESS: at 86.71% examples, 450267 words/s, in_qsize 17, out_qsize 1
# 2022-05-19 04:16:18,470 : INFO : EPOCH 10 - PROGRESS: at 87.00% examples, 450218 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 04:16:19,500 : INFO : EPOCH 10 - PROGRESS: at 87.30% examples, 450279 words/s, in_qsize 12, out_qsize 7
# 2022-05-19 04:16:20,524 : INFO : EPOCH 10 - PROGRESS: at 87.59% examples, 450262 words/s, in_qsize 18, out_qsize 6
# 2022-05-19 04:16:21,530 : INFO : EPOCH 10 - PROGRESS: at 87.89% examples, 450383 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:16:22,552 : INFO : EPOCH 10 - PROGRESS: at 88.18% examples, 450417 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 04:16:23,562 : INFO : EPOCH 10 - PROGRESS: at 88.46% examples, 450399 words/s, in_qsize 15, out_qsize 5
# 2022-05-19 04:16:24,574 : INFO : EPOCH 10 - PROGRESS: at 88.76% examples, 450460 words/s, in_qsize 15, out_qsize 2
# 2022-05-19 04:16:25,590 : INFO : EPOCH 10 - PROGRESS: at 89.05% examples, 450499 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:16:26,596 : INFO : EPOCH 10 - PROGRESS: at 89.34% examples, 450572 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:16:27,597 : INFO : EPOCH 10 - PROGRESS: at 89.64% examples, 450627 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:16:28,650 : INFO : EPOCH 10 - PROGRESS: at 89.93% examples, 450618 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:16:29,707 : INFO : EPOCH 10 - PROGRESS: at 90.20% examples, 450482 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 04:16:30,715 : INFO : EPOCH 10 - PROGRESS: at 90.45% examples, 450323 words/s, in_qsize 15, out_qsize 2
# 2022-05-19 04:16:31,746 : INFO : EPOCH 10 - PROGRESS: at 90.68% examples, 450045 words/s, in_qsize 18, out_qsize 4
# 2022-05-19 04:16:32,765 : INFO : EPOCH 10 - PROGRESS: at 90.90% examples, 449699 words/s, in_qsize 18, out_qsize 0
# 2022-05-19 04:16:33,801 : INFO : EPOCH 10 - PROGRESS: at 91.12% examples, 449400 words/s, in_qsize 17, out_qsize 5
# 2022-05-19 04:16:34,825 : INFO : EPOCH 10 - PROGRESS: at 91.35% examples, 449094 words/s, in_qsize 20, out_qsize 2
# 2022-05-19 04:16:35,838 : INFO : EPOCH 10 - PROGRESS: at 91.57% examples, 448805 words/s, in_qsize 19, out_qsize 5
# 2022-05-19 04:16:36,915 : INFO : EPOCH 10 - PROGRESS: at 91.80% examples, 448432 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:16:37,954 : INFO : EPOCH 10 - PROGRESS: at 92.01% examples, 448051 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:16:38,996 : INFO : EPOCH 10 - PROGRESS: at 92.23% examples, 447709 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:16:40,012 : INFO : EPOCH 10 - PROGRESS: at 92.47% examples, 447513 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 04:16:41,037 : INFO : EPOCH 10 - PROGRESS: at 92.67% examples, 447117 words/s, in_qsize 19, out_qsize 1
# 2022-05-19 04:16:42,044 : INFO : EPOCH 10 - PROGRESS: at 92.92% examples, 446951 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:16:43,052 : INFO : EPOCH 10 - PROGRESS: at 93.14% examples, 446659 words/s, in_qsize 11, out_qsize 0
# 2022-05-19 04:16:44,067 : INFO : EPOCH 10 - PROGRESS: at 93.34% examples, 446279 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:16:45,067 : INFO : EPOCH 10 - PROGRESS: at 93.55% examples, 445937 words/s, in_qsize 20, out_qsize 4
# 2022-05-19 04:16:46,088 : INFO : EPOCH 10 - PROGRESS: at 93.82% examples, 445873 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 04:16:47,096 : INFO : EPOCH 10 - PROGRESS: at 94.10% examples, 445907 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:16:48,106 : INFO : EPOCH 10 - PROGRESS: at 94.40% examples, 445983 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:16:49,115 : INFO : EPOCH 10 - PROGRESS: at 94.69% examples, 446033 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 04:16:50,155 : INFO : EPOCH 10 - PROGRESS: at 95.00% examples, 446152 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:16:51,167 : INFO : EPOCH 10 - PROGRESS: at 95.29% examples, 446181 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:16:52,180 : INFO : EPOCH 10 - PROGRESS: at 95.59% examples, 446264 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:16:53,188 : INFO : EPOCH 10 - PROGRESS: at 95.89% examples, 446361 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:16:54,193 : INFO : EPOCH 10 - PROGRESS: at 96.19% examples, 446479 words/s, in_qsize 20, out_qsize 0
# 2022-05-19 04:16:55,243 : INFO : EPOCH 10 - PROGRESS: at 96.47% examples, 446441 words/s, in_qsize 20, out_qsize 1
# 2022-05-19 04:16:56,252 : INFO : EPOCH 10 - PROGRESS: at 96.74% examples, 446388 words/s, in_qsize 19, out_qsize 3
# 2022-05-19 04:16:57,261 : INFO : EPOCH 10 - PROGRESS: at 97.07% examples, 446581 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 04:16:58,270 : INFO : EPOCH 10 - PROGRESS: at 97.35% examples, 446616 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:16:59,347 : INFO : EPOCH 10 - PROGRESS: at 97.66% examples, 446666 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 04:17:00,371 : INFO : EPOCH 10 - PROGRESS: at 97.96% examples, 446705 words/s, in_qsize 16, out_qsize 7
# 2022-05-19 04:17:01,403 : INFO : EPOCH 10 - PROGRESS: at 98.26% examples, 446769 words/s, in_qsize 17, out_qsize 2
# 2022-05-19 04:17:02,424 : INFO : EPOCH 10 - PROGRESS: at 98.55% examples, 446807 words/s, in_qsize 19, out_qsize 0
# 2022-05-19 04:17:03,457 : INFO : EPOCH 10 - PROGRESS: at 98.84% examples, 446813 words/s, in_qsize 17, out_qsize 4
# 2022-05-19 04:17:04,494 : INFO : EPOCH 10 - PROGRESS: at 99.14% examples, 446874 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 04:17:05,518 : INFO : EPOCH 10 - PROGRESS: at 99.46% examples, 447042 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 04:17:06,527 : INFO : EPOCH 10 - PROGRESS: at 99.73% examples, 446987 words/s, in_qsize 18, out_qsize 1
# 2022-05-19 04:17:07,246 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2022-05-19 04:17:07,257 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2022-05-19 04:17:07,264 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2022-05-19 04:17:07,297 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2022-05-19 04:17:07,311 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2022-05-19 04:17:07,345 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2022-05-19 04:17:07,349 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2022-05-19 04:17:07,354 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-05-19 04:17:07,355 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-05-19 04:17:07,356 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-05-19 04:17:07,362 : INFO : EPOCH - 10 : training on 222967702 raw words (160921133 effective words) took 359.9s, 447151 effective words/s
# 2022-05-19 04:17:07,363 : INFO : Word2Vec lifecycle event {'msg': 'training on 2229677020 raw words (1609190409 effective words) took 3533.6s, 455400 effective words/s', 'datetime': '2022-05-19T04:17:07.363141', 'gensim': '4.1.2', 'python': '3.7.13 (default, Apr 24 2022, 01:04:09) \n[GCC 7.5.0]', 'platform': 'Linux-5.4.188+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'train'}
# 2022-05-19 04:17:07,364 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec(vocab=94068, vector_size=50, alpha=0.025)', 'datetime': '2022-05-19T04:17:07.364358', 'gensim': '4.1.2', 'python': '3.7.13 (default, Apr 24 2022, 01:04:09) \n[GCC 7.5.0]', 'platform': 'Linux-5.4.188+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'created'}
# 2022-05-19 04:17:07,365 : INFO : Word2Vec lifecycle event {'fname_or_handle': 'drive/MyDrive/Data/NLP2022/word2vec3.bin', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2022-05-19T04:17:07.365669', 'gensim': '4.1.2', 'python': '3.7.13 (default, Apr 24 2022, 01:04:09) \n[GCC 7.5.0]', 'platform': 'Linux-5.4.188+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'saving'}
# 2022-05-19 04:17:07,367 : INFO : not storing attribute cum_table
# 2022-05-19 04:17:07,757 : INFO : saved drive/MyDrive/Data/NLP2022/word2vec3.bin

# %%
# Vocab size of word2vec model
print(f"Number of words= {len(list(model.wv.index_to_key))}")
# Out:
# Number of words= 94068

# %%
'''
 Function to implement RNN with specifications mentioned in class where
 the sum of the hidden values are taken as the sentence vectors. We have
 also randomly initialised the matrix embeddings.
'''
def sentence_embedding(word_vec_size, sent_vec_size):
  # Initialise null matrix for sentence vectors
  sent_vec_mat = np.zeros((len(sentences), sent_vec_size))
  # Initialising random weights
  W = np.random.normal(0, 0.01, (sent_vec_size, word_vec_size))
  U = np.random.normal(0, 0.01, (sent_vec_size, sent_vec_size))
  h = np.zeros(sent_vec_size)
  for n, sent in tqdm(enumerate(sentences)):
    for word in re.split(' ', sent.strip()):
      try:
        x = model.wv[word]
        x = scipy.stats.zscore(x)
        h = np.tanh((U@h.T) + (W@x.T))
      except:
        None
      sent_vec_mat[n] += h
      h = h/sent_vec_size
  return sent_vec_mat

# Function to calculate cosine similarity between two vectors
def cosine_similarity(x, y):
  return 1-scipy.spatial.distance.cosine(x , y)

'''
 Function which takes index of a sentence, calculates cosine 
 similarity between that and the rest of the sentences and displays
 10 most similar sentences
'''
def print_sim_sentences(sent_idx):
  print('-'*150, '\n')
  cos = list()
  for i in range(len(sentences)):
    cos.append(cosine_similarity(sv_mat[i], sv_mat[sent_idx]))
  cos = torch.from_numpy(np.array(cos))

  values, idx = torch.topk(cos, k=11, axis=-1)
  for i in range(1,11):
    print(f"{sentences[idx[i]]}\nScore= {float(cos[idx[i]])}", end='\n\n')

'''
 Function which takes an array of sentence indices and displays
 10 most similar sentence for each of them along with the cosine
 similarity scores
'''
def sim_sentences(rand_idx):
  for i, idx in enumerate(rand_idx):
    print('='*150)
    print(f"\033[1m Case {i+1}: \033[0;0m")
    print('Most similar sentences to: \n', sentences[idx], '\n')
    print_sim_sentences(idx)
  print('='*150)

# Obtain sentence embedding from RNN
sv_mat= sentence_embedding(50,100)
# Out:
# 130082it [05:17, 409.45it/s]

# %%
# Randomly choose 5 sentences to find similar sentences
idx = np.random.randint(0, len(sentences), 5)
print('5 random sentences: ')
print('-'*150, '\n')
for i in idx:
    print(sentences[i], '\n')
# Out:
# 5 random sentences:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
#
# rapamycin has no effect on the expression of hla abc in culture treated with ifn as well.
#
# coronaviruses are nonsegmented enveloped posit that is ense single strand rna viruses.
#
# some tumors had marked cellular anaplasia or nuclear atypia.
#
# ppm respect that is wh that is carbon appeared at.
#
# low histam that is diet was initiated and repeat tryptase rema that is elevated.

# %%
# Display 10 similar sentences for each of the 5 randomly chosen sentence
sim_sentences(idx)
# Out:
# ======================================================================================================================================================
#  Case 1:
# Most similar sentences to:
#  rapamycin has no effect on the expression of hla abc in culture treated with ifn as well.
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
#
# in normal culture mtor inhibition has no effect on the expression of hla abc.
# Score= 0.8599215903032725
#
# on the other hand dihydroxyvitamin induced ddit in a concentration dependent manner in hulm cells.
# Score= 0.8051176835340293
#
# ifn production in the absence of fucose treatment was set as the control.
# Score= 0.7845211469280885
#
# as shown in figure the metabolic activity of vero cells pretreated with the intracellular extracts of ln.
# Score= 0.7804139060725089
#
# when htra was depleted by shrna the expression of id and was largely unaffected.
# Score= 0.7787930942158968
#
# after of treatment with pge the bim fluorescence intensity was attenuated compared with that in the dkd group.
# Score= 0.7739735649535602
#
# in contrast sb an inhibitor of mapk blocked the stimulation of vegf gene expression by gonadotropins and fsk.
# Score= 0.7729880784423291
#
# in contrast to sirna knockdown of vcp treatment with nms did not result in increased ie expression.
# Score= 0.7692870053392561
#
# in contrast treatment of both the vector control and tlr dn cells with pdg similarly reduced il secretion.
# Score= 0.7689622261090674
#
# the transfected cells expressed lower protein levels of ef a when compared with the control sirna transfected cells.
# Score= 0.766659910923799
#
# ======================================================================================================================================================
#  Case 2:
# Most similar sentences to:
#  coronaviruses are nonsegmented enveloped posit that is ense single strand rna viruses.
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
#
# influenza viruses are enveloped viruses with a segmented negat that is strand rna genome.
# Score= 0.9506763501054266
#
# viruses from the rhabdoviridae family are single stranded negat that is sense rna viruses.
# Score= 0.9353312274763108
#
# the coronaviruses are large enveloped posit that is stranded rna viruses.
# Score= 0.9320838905030207
#
# they are enveloped viruses with a posit that is sense single stranded rna genome.
# Score= 0.9166197644158834
#
# coronaviruses are enveloped viruses with a large singlestranded rna genome of posit that is polarity.
# Score= 0.9063848538040443
#
# coronaviruses are large pleomorphic enveloped posit that is sense single stranded rna viruses belonging to the coronaviridae family.
# Score= 0.9046392700879894
#
# covs are enveloped posit that is sense rna viruses and possess the largest genome of all rna viruses.
# Score= 0.901677299696474
#
# paramyxoviridae family is constituted by singlestranded negat that is sense rna genome viruses.
# Score= 0.9012710732429191
#
# nodavirus are non enveloped viruses with a genome consisting in two molecules of singlestranded posit that is sense rna.
# Score= 0.8966997031091422
#
# sars cov is enveloped posit that is sense ssrna virus.
# Score= 0.8957300342522072
#
# ======================================================================================================================================================
#  Case 3:
# Most similar sentences to:
#  some tumors had marked cellular anaplasia or nuclear atypia.
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
#
# additionally neutrophils may exhibit changes in morphology such as toxic granulation dhle bodies and cytoplasmic vacuoles.
# Score= 0.8555925022851399
#
# neutrophils were usually found in those tumors that had histologic foci of necrosis and focal accumulations.
# Score= 0.8255258066867025
#
# brain biopsy showed nonspecific necrotic neurons with featureless nuclei and pyknotic cells.
# Score= 0.8114468048970975
#
# h tumor cells resemble mature ciliary epithelium and usually have very little associated stroma.
# Score= 0.8070784687235555
#
# numerous neutrophils macrophages some small giant cells fibrin and in some areas neo vascularization were observed.
# Score= 0.8066082350011579
#
# keratinization marked hyperplasia with rete ridge formation and pigmentation are commonly seen.
# Score= 0.8036882071164376
#
# pronounced papillary dermal oedema and spongiosis are often present.
# Score= 0.8009634967753316
#
# balloon cells with foamy cytoplasm and very distinct cell boundaries are frequent in some tumors.
# Score= 0.8000077459650288
#
# cytoplasmic vacuolation of neutrophils is encountered less often than toxic granules and dhle bodies.
# Score= 0.7992554171804646
#
# endometriosis lesions contain endometrial glands and stroma along with nerves capillaries and leukocytes.
# Score= 0.7984973212831502
#
# ======================================================================================================================================================
#  Case 4:
# Most similar sentences to:
#  ppm respect that is wh that is carbon appeared at.
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
#
# ppm respect that is whereas linked to a chlor that is atom appeared at.
# Score= 0.8659461262300582
#
# ppm wh that is proton at appeared at.
# Score= 0.8109652428024043
#
# respect that is antibody concentrations were.
# Score= 0.796721569103827
#
# the respect that is adhes that is ratios were.
# Score= 0.7936972963368875
#
# g respect that is y. this has reduced to g and g respect that is during.
# Score= 0.7936083152647827
#
# pept that is bonds per rain.
# Score= 0.7918645026295272
#
# respect that is with respect to temperature.
# Score= 0.7915876294221829
#
# mg respect that is wh that is on propofol it was.
# Score= 0.7894417374278984
#
# mean triglycer that is revealed doserelated increases and maximum values were obta that is also at.
# Score= 0.7868291523459151
#
# m respect that is moracin vs moracin.
# Score= 0.7724833678676817
#
# ======================================================================================================================================================
#  Case 5:
# Most similar sentences to:
#  low histam that is diet was initiated and repeat tryptase rema that is elevated.
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
#
# basel that is tryptase was elevated.
# Score= 0.8835112381458896
#
# magnesium serum levels increased during administration of mgso and rema that is elevated that is until after surgery.
# Score= 0.8539850078511144
#
# dobutam that is was progress that is reduced and discontinued.
# Score= 0.8508131696465361
#
# in vivo serum that is levels were diminished and act that is cutaneous anaphylaxis reaction were suppressed.
# Score= 0.8494489132292963
#
# after enoxaparin was applied d that is rema that is elevated.
# Score= 0.8400760721589591
#
# mg dl act that is phase.
# Score= 0.836456937805497
#
# thyrox that is is iod that is and regulates body metabolism.
# Score= 0.833833198242392
#
# hyperchloremia was def that is as serum chlor that is of meq or greater.
# Score= 0.8336354173572268
#
# inducing normothermia with temperature modulating dev that is is often associated with significant sh that is ing.
# Score= 0.8246808108742112
#
# plasma sflt decl that is in controls but increased in preeclamptic that is.
# Score= 0.822440958925765
#
# ======================================================================================================================================================

# %% [markdown]
# **Distance Measure:** The distance measure used in this RNN is the cosine similarity which is given by:
# $$sim(x,y) = \dfrac{x.y}{||x||\ ||y||}$$
# where $||x||$ is the Euclidean norm of the vector x. This measure is prevalently used in such cases since it measures the angle between the vectors in the vector-space (which is 100 dimensional in our case). Another measure that could have been used is the usual Euclidean distance. The cosine similarity was used during word vectors and it is justified using it for sentence vectors since we are obtaining the sentence vectors by adding up the hidden values which is essentially averaging. Since there is no training involved we are taking the sum, otherwise we would have taken the last hidden value.
